# %%
# CPU实时监控
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import psutil as p

import os
import subprocess

#cmd1 = 'adb connect  10.10.25.10:5555'
#subprocess.Popen(cmd1, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)

POINTS = 10
fig, ax = plt.subplots(8,1)

# ax.set_ylim([0, 10])
# ax.set_xlim([0, POINTS])
# ax.set_autoscale_on(False)
# ax.set_xticks([])
# ax.set_yticks(range(0, 10, 2))
ax.grid(True)


x0 = []
x1 = []
x2 = []
x3 = []
x4 = []
x5 = []
x6 = []
x7 = []


def get_cpu_usage():
    for num in range(10) :
        for i in range(8) :
#             maxFreq_result = subprocess.Popen(cmdCpuMaxFreq, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
    #         maxFreq_output, maxFreq_error = maxFreq_result.communicate(timeout=600)

            cmdCpuCurFreq = 'adb shell cat /sys/devices/system/cpu/cpu' + "{}".format(i) + '/cpufreq/cpuinfo_cur_freq'
    #         cmdCpuMaxFreq = 'adb shell cat /sys/devices/system/cpu/cpu' + "{}".format(i) + '/cpufreq/cpuinfo_max_freq'
    #         cmdCpuMinFreq = 'adb shell cat /sys/devices/system/cpu/cpu' + "{}".format(i) + '/cpufreq/cpuinfo_min_freq'
            curFreq_result = subprocess.Popen(cmdCpuCurFreq, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
            curFreq_output, curFreq_error = curFreq_result.communicate(timeout=600)

    #         minFreq_result = subprocess.Popen(cmdCpuMinFreq, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
    #         minFreq_output, minFreq_error = minFreq_result.communicate(timeout=600)

            if i == 0 :
                x0.append(int(curFreq_output.decode()))
            elif i == 1 :
                x1.append(int(curFreq_output.decode()))
            elif i == 2 :
                x2.append(int(curFreq_output.decode()))
            elif i == 3 :
                x3.append(int(curFreq_output.decode()))
            elif i == 4 :
                x4.append(int(curFreq_output.decode()))
            elif i == 5 :
                x5.append(int(curFreq_output.decode()))
            elif i == 6 :
                x6.append(int(curFreq_output.decode()))
            elif i == 7 :
                x7.append(int(curFreq_output.decode()))
            
#             print(x0)
#             print(x1)
#             print(x2)
#             print(x3)
#             print(x4)
#             print(x5)
#             print(x6)
#             print(x7)

get_cpu_usage()            
            
l_cpu0 = ax.plot(range(POINTS), x0, label='cpu0')
l_cpu1 = ax.plot(range(POINTS), x1, label='cpu1')
l_cpu2 = ax.plot(range(POINTS), x2, label='cpu2')
l_cpu3 = ax.plot(range(POINTS), x3, label='cpu3')
l_cpu4 = ax.plot(range(POINTS), x4, label='cpu4')
l_cpu5 = ax.plot(range(POINTS), x5, label='cpu5')
l_cpu6 = ax.plot(range(POINTS), x6, label='cpu6')
l_cpu7 = ax.plot(range(POINTS), x7, label='cpu7')
# l_cpuMaxFreq, = ax.plot(range(POINTS), cpuMaxFreq, label='cpuMaxFreq')
# l_cpuMinFreq, = ax.plot(range(POINTS), cpuMinFreq, label='cpuMinFreq')
ax.legend(loc='upper center', ncol=4, prop=font_manager.FontProperties(size=10))
bg = fig.canvas.copy_from_bbox(ax.bbox)            

def OnTimer(ax):

    l_cpu0.set_ydata(x0)
    l_cpu1.set_ydata(x1)
    l_cpu2.set_ydata(x2)
    l_cpu3.set_ydata(x3)
    l_cpu4.set_ydata(x4)
    l_cpu5.set_ydata(x5)
    l_cpu6.set_ydata(x6)
    l_cpu7.set_ydata(x7)
    
    
    while True:
        try:
            ax.draw_artist(l_cpu0)
            ax.draw_artist(l_cpu1)
            ax.draw_artist(l_cpu2)
            ax.draw_artist(l_cpu3)
            ax.draw_artist(l_cpu4)
            ax.draw_artist(l_cpu5)
            ax.draw_artist(l_cpu6)
            
#             print('okokok')
            break
        except:
#             print('error')
            pass
    ax.figure.canvas.draw()


    
def start_monitor():
#     get_cpu_usage()
    timer = fig.canvas.new_timer(interval=10)
#     print("------3333-----")
    timer.add_callback(OnTimer, ax)
#     print('***1*', cpuCurFreq)
#     print('***2*', cpuMaxFreq)
#     print('***3*', cpuMinFreq)
#     print("------4444-----")
    timer.start()
    plt.show()
#     plt.pause(1)
#     plt.savefig("a.png")
    

if __name__ == '__main__':
    start_monitor()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1840/3760989366.py in <module>
#      19 # ax.set_xticks([])
#      20 # ax.set_yticks(range(0, 10, 2))
# ---> 21 ax.grid(True)
#      22
#      23
#
# AttributeError: 'numpy.ndarray' object has no attribute 'grid'

# %%
import os
import subprocess
import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib qt5
from IPython import display
import random
import pandas as pd

cmd1 = 'adb connect  10.10.25.2:5555'
subprocess.Popen(cmd1, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
 
fig = plt.figure()

ax0 = fig.add_subplot(811)
ax1 = fig.add_subplot(812)
ax2 = fig.add_subplot(813)
ax3 = fig.add_subplot(814)
ax4 = fig.add_subplot(815)
ax5 = fig.add_subplot(816)
ax6 = fig.add_subplot(817)
ax7 = fig.add_subplot(818)


ax0.set_xlabel('Time')
ax0.set_ylabel('cpu0')
ax0.set_title('')
ax1.set_xlabel('Time')
ax1.set_ylabel('cpu1')
ax2.set_xlabel('Time')
ax2.set_ylabel('cpu2')
ax3.set_xlabel('Time')
ax3.set_ylabel('cpu3')
ax4.set_xlabel('Time')
ax4.set_ylabel('cpu4')
ax5.set_xlabel('Time')
ax5.set_ylabel('cpu5')
ax6.set_xlabel('Time')
ax6.set_ylabel('cpu6')
ax7.set_xlabel('Time')
ax7.set_ylabel('cpu7')

line = None
plt.grid(True) #添加网格
plt.ion()  #interactive mode on
obsX = []


x0 = []
x1 = []
x2 = []
x3 = []
x4 = []
x5 = []
x6 = []
x7 = []

test1 = []
test2 = []
test3 = []
test4 = []
test5 = []


t0 = time.time()#round(time.time() * 1000)
# int(round(t * 1000))

# while True:
for i in range(200) :

#     t0 = time.time()
    
    x0.append(random.random())
    x1.append(random.random())
    x2.append(random.random())
    x3.append(random.random())
    x4.append(random.random())
    x5.append(random.random())
    x6.append(random.random())
    x7.append(random.random())
    
#     t1 = time.time() - t0
#     test1.append(t1)
#     df = pd.DataFrame(list(test1)).add_prefix("time")
#     df.to_csv("time1.csv")
    
#     t2 = time.time()
#     for i in range(8) :
#         cmdCpuCurFreq = 'adb shell cat /sys/devices/system/cpu/cpu' + "{}".format(i) + '/cpufreq/cpuinfo_cur_freq'
#         curFreq_result = subprocess.Popen(cmdCpuCurFreq, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
#         curFreq_output, curFreq_error = curFreq_result.communicate(timeout=600)

#         if i == 0 :
#             x0.append(int(curFreq_output.decode()) / 1000000)
# #             print('x0', x0)
#         elif i == 1 :
#             x1.append(int(curFreq_output.decode()) / 1000000)
# #             print('x1', x1)
#         elif i == 2 :
#             x2.append(int(curFreq_output.decode()) / 1000000)
# #             print('x2', x2)
#         elif i == 3 :
#             x3.append(int(curFreq_output.decode()) / 1000000)
# #             print('x3', x3)
#         elif i == 4 :
#             x4.append(int(curFreq_output.decode()) / 1000000)
# #             print('x4', x4)
#         elif i == 5 :
#             x5.append(int(curFreq_output.decode()) / 1000000)
# #             print('x5', x5)
#         elif i == 6 :
#             x6.append(int(curFreq_output.decode()) / 1000000)
# #             print('x6', x6)
#         elif i == 7 :
#             x7.append(int(curFreq_output.decode()) / 1000000)
# #             print('x7', x7)
    
#     t3 = time.time() - t2#round(time.time() * 1000) - t0
#     test2.append(t3)
#     df = pd.DataFrame(list(test2)).add_prefix("time")
#     df.to_csv("time2.csv")    
    
    t = time.time()
    obsX.append(t)
    
#     t_4 = time.time()
    if line is None:
        line0 = ax0.plot(obsX, x0)
        line1 = ax1.plot(obsX, x1)
        line2 = ax2.plot(obsX, x2)
        line3 = ax3.plot(obsX, x3)
        line4 = ax4.plot(obsX, x4)
        line5 = ax5.plot(obsX, x5)
        line6 = ax6.plot(obsX, x6)
        line7 = ax7.plot(obsX, x7)
#     t_4_4 = time.time() - t_4
#     test3.append(t_4_4)
#     df = pd.DataFrame(list(test3)).add_prefix("time")
#     df.to_csv("time3.csv")   
    
    t_5 = time.time()
    ax0.set_xlim([t-5,t + 1])
    ax1.set_xlim([t-5,t + 1])
    ax2.set_xlim([t-5,t + 1])
    ax3.set_xlim([t-5,t + 1])
    ax4.set_xlim([t-5,t + 1])
    ax5.set_xlim([t-5,t + 1])
    ax6.set_xlim([t-5,t + 1])
    ax7.set_xlim([t-5,t + 1])
#     ax0.set_ylim([0.3, 1.804]) #1.804
#     t_5_5 = time.time() - t_5
#     test4.append(t_5_5)
    df = pd.DataFrame(list(test4)).add_prefix("time")
#     df.to_csv("time4.csv")
    
#     t_6 = time.time()
    plt.pause(0.03)
#     t_6_6 = time.time() - t_6
#     test5.append(t_6_6)
#     df = pd.DataFrame(list(test5)).add_prefix("time")
#     df.to_csv("time5.csv")
    
#     ax0.cla()
#     ax1.cla()
#     ax2.cla()
#     ax3.cla()
#     ax4.cla()
#     ax5.cla()
#     ax6.cla()
#     ax7.cla()

plt.show()

# %%
# %matplotlib qt5
from IPython import display
import matplotlib.pyplot as plt
import pandas as pd
import time
import datetime
import random
import threading
import queue
import os

fig = plt.figure()

ax0 = fig.add_subplot(811)
ax1 = fig.add_subplot(812)
ax2 = fig.add_subplot(813)
ax3 = fig.add_subplot(814)
ax4 = fig.add_subplot(815)
ax5 = fig.add_subplot(816)
ax6 = fig.add_subplot(817)
ax7 = fig.add_subplot(818)


ax0.set_xlabel('Time')
ax0.set_ylabel('cpu0')
ax0.set_title('')
ax1.set_xlabel('Time')
ax1.set_ylabel('cpu1')
ax2.set_xlabel('Time')
ax2.set_ylabel('cpu2')
ax3.set_xlabel('Time')
ax3.set_ylabel('cpu3')
ax4.set_xlabel('Time')
ax4.set_ylabel('cpu4')
ax5.set_xlabel('Time')
ax5.set_ylabel('cpu5')
ax6.set_xlabel('Time')
ax6.set_ylabel('cpu6')
ax7.set_xlabel('Time')
ax7.set_ylabel('cpu7')


x0 = []
x1 = []
x2 = []
x3 = []
x4 = []
x5 = []
x6 = []
x7 = []
obsX = []

t0 = time.time()#round(time.time() * 1000)
# int(round(t * 1000))

# q = queue.Queue(maxsize=50)

line = None
plt.grid(True) #添加网格
plt.ion()  #interactive mode on

plt.xticks(rotation = 90)


def producer() :
    count = 0
    num = 0
    
    print("first")
    
    while True:
        # 使用随机数进行测试
        x0.append(random.random())
        x1.append(random.random())
        x2.append(random.random())
        x3.append(random.random())
        x4.append(random.random())
        x5.append(random.random())
        x6.append(random.random())
        x7.append(random.random())
        
#         for i in range(8) :
#             cmdCpuCurFreq = 'adb shell cat /sys/devices/system/cpu/cpu' + "{}".format(i) + '/cpufreq/cpuinfo_cur_freq'
#             curFreq_result = subprocess.Popen(cmdCpuCurFreq, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
#             curFreq_output, curFreq_error = curFreq_result.communicate(timeout=600)

#             if i == 0 :
#                 x0.append(int(curFreq_output.decode()) / 1000000)
#     #             print('x0', x0)
#             elif i == 1 :
#                 x1.append(int(curFreq_output.decode()) / 1000000)
#     #             print('x1', x1)
#             elif i == 2 :
#                 x2.append(int(curFreq_output.decode()) / 1000000)
#     #             print('x2', x2)
#             elif i == 3 :
#                 x3.append(int(curFreq_output.decode()) / 1000000)
#     #             print('x3', x3)
#             elif i == 4 :
#                 x4.append(int(curFreq_output.decode()) / 1000000)
#     #             print('x4', x4)
#             elif i == 5 :
#                 x5.append(int(curFreq_output.decode()) / 1000000)
#     #             print('x5', x5)
#             elif i == 6 :
#                 x6.append(int(curFreq_output.decode()) / 1000000)
#     #             print('x6', x6)
#             elif i == 7 :
#                 x7.append(int(curFreq_output.decode()) / 1000000)
    #             print('x7', x7)
        
        t = (datetime.datetime.now()).strftime("%H:%M:%S.%f") #- t0#round(time.time() * 1000) - t0
        obsX.append(t)

    #     df = pd.DataFrame(list(zip(*[list1, list2, list3]))).add_prefix('Col')
        df0 = pd.DataFrame(list(obsX)).add_prefix('time')
        df1 = pd.DataFrame(list(zip(*[x0, x1, x2, x3, x4, x5, x6, x7]))).add_prefix('cpu')
        df = pd.concat([df0, df1], axis=1, ignore_index=False)
        df.to_csv('file.csv', index=False)
        
#         print("1111111")
        
        count += 1
        if count > 50 :
            count = 0
            num += 1
            
            time.sleep(0.01)
#             df.plot(x='time0', y='cpu0')
        if num > 3:
            num = 0
            break
#             continue
    #     print(df)
        
#         print("222222")
#         plt.show()


if __name__ == '__main__' :
    for i in range(20) :
#     while True :
        p = threading.Thread(target=producer)
        #     c = threading.Thread(target=consumer)

        p.start()
        p.join()

        while True :
            df_c = pd.read_csv("file.csv")
            time0 = df_c['time0']
            x00 = df_c['cpu0']

            print(x00)
            print(time0)

            if line is None:
                line0 = ax0.plot(time0, x00)
                line1 = ax1.plot(obsX, x1)
                line2 = ax2.plot(obsX, x2)
                line3 = ax3.plot(obsX, x3)
                line4 = ax4.plot(obsX, x4)
                line5 = ax5.plot(obsX, x5)
                line6 = ax6.plot(obsX, x6)
                line7 = ax7.plot(obsX, x7)
    #         print("333333333")
            t = datetime.datetime.now()
            ax0.set_xlim((t - datetime.timedelta(seconds=5)).strftime("%H:%M:%S.%f"),(t + datetime.timedelta(seconds=1)).strftime("%H:%M:%S"))
            ax1.set_xlim((t - datetime.timedelta(seconds=5)).strftime("%H:%M:%S.%f"),(t + datetime.timedelta(seconds=1)).strftime("%H:%M:%S"))
            ax2.set_xlim((t - datetime.timedelta(seconds=5)).strftime("%H:%M:%S.%f"),(t + datetime.timedelta(seconds=1)).strftime("%H:%M:%S"))
            ax3.set_xlim((t - datetime.timedelta(seconds=5)).strftime("%H:%M:%S.%f"),(t + datetime.timedelta(seconds=1)).strftime("%H:%M:%S"))
            ax4.set_xlim((t - datetime.timedelta(seconds=5)).strftime("%H:%M:%S.%f"),(t + datetime.timedelta(seconds=1)).strftime("%H:%M:%S"))
            ax5.set_xlim((t - datetime.timedelta(seconds=5)).strftime("%H:%M:%S.%f"),(t + datetime.timedelta(seconds=1)).strftime("%H:%M:%S"))
            ax6.set_xlim((t - datetime.timedelta(seconds=5)).strftime("%H:%M:%S.%f"),(t + datetime.timedelta(seconds=1)).strftime("%H:%M:%S"))
            ax7.set_xlim((t - datetime.timedelta(seconds=5)).strftime("%H:%M:%S.%f"),(t + datetime.timedelta(seconds=1)).strftime("%H:%M:%S"))

            
            plt.pause(0.0001)
            
#             os.remove("file.csv")
            break
    
#     consumer()
#     c.start()
# Out:
# first
# 0      0.944669
# 1      0.740827
# 2      0.661783
# 3      0.181828
# 4      0.320440
#          ...
# 199    0.532399
# 200    0.745705
# 201    0.843282
# 202    0.047062
# 203    0.619657
# Name: cpu0, Length: 204, dtype: float64
# 0      12:10:30.888239
# 1      12:10:30.891231
# 2      12:10:30.893226
# 3      12:10:30.895221
# 4      12:10:30.897216
#             ...
# 199    12:10:31.535516
# 200    12:10:31.539505
# 201    12:10:31.543494
# 202    12:10:31.547485
# 203    12:10:31.551474
# Name: time0, Length: 204, dtype: object
# first
# 0      0.944669
# 1      0.740827
# 2      0.661783
# 3      0.181828
# 4      0.320440
#          ...
# 403    0.366200
# 404    0.331440
# 405    0.346691
# 406    0.886438
# 407    0.272177
# Name: cpu0, Length: 408, dtype: float64
# 0      12:10:30.888239
# 1      12:10:30.891231
# 2      12:10:30.893226
# 3      12:10:30.895221
# 4      12:10:30.897216
#             ...
# 403    12:10:34.732010
# 404    12:10:34.738990
# ...

# %%
(datetime.datetime.now()).strftime("%H:%M:%S.%f")
# Out:
# '12:02:31.536992'

# %%
import threading
import time
import queue
 
 
q = queue.Queue(maxsize=10)
 
 
def producer(name):  #生产者
    count = 0
    while True:
        q.put("骨头%s" % count)
        print("生产了骨头", count)
        count += 1
        time.sleep(0.5)
 
 
def consumer(name):  #消费者
    while True:
        print("[%s]取到[%s]并且吃了它..." % (name, q.get()))
        time.sleep(1)
         
p = threading.Thread(target=producer, args=("Tim",))
c1 = threading.Thread(target=consumer, args=("King",))
c2 = threading.Thread(target=consumer, args=("Wang",))
 
p.start()
c1.start()
c2.start()
# Out:
# 生产了骨头 0
# [King]取到[骨头0]并且吃了它...
# 生产了骨头[Wang]取到[骨头272]并且吃了它...
#  272
# 生产了骨头[Wang]取到[骨头78]并且吃了它...
#  78
# 生产了骨头[Wang]取到[骨头1]并且吃了它... 1
#
# 生产了骨头[King]取到[骨头273]并且吃了它...
#  273
# 生产了骨头[King]取到[骨头79]并且吃了它...
#  79
# 生产了骨头 2
# [King]取到[骨头2]并且吃了它...
# 生产了骨头[Wang]取到[骨头274]并且吃了它... 274
#
# 生产了骨头[Wang]取到[骨头80]并且吃了它... 80
#
# 生产了骨头[Wang]取到[骨头3]并且吃了它...
#  3
# 生产了骨头[King]取到[骨头275]并且吃了它...
#  275
# 生产了骨头[King]取到[骨头81]并且吃了它...
#  81
# 生产了骨头 4
# [King]取到[骨头4]并且吃了它...
# 生产了骨头 276
# [Wang]取到[骨头276]并且吃了它...
# 生产了骨头[Wang]取到[骨头82]并且吃了它...
#  82
# 生产了骨头[Wang]取到[骨头5]并且吃了它...
#  5
# 生产了骨头[King]取到[骨头277]并且吃了它...
#  277
# 生产了骨头[King]取到[骨头83]并且吃了它...
#  83
# 生产了骨头 6
# [King]取到[骨头6]并且吃了它...
# 生产了骨头 278
# [Wang]取到[骨头278]并且吃了它...
# 生产了骨头[Wang]取到[骨头84]并且吃了它... 84
#
# 生产了骨头[Wang]取到[骨头7]并且吃了它... 7

# %%
import os
import subprocess

cmd1 = 'adb connect  10.10.25.10:5555'
cmd2 = 'adb shell cat /sys/devices/system/cpu/cpu0/cpufreq/cpuinfo_cur_freq'
subprocess.Popen(cmd1, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)

x0 = []
x1 = []
x2 = []
x3 = []
x4 = []
x5 = []
x6 = []
x7 = []

# for num in range(10) :
for i in range(8) :
    maxFreq_result = subprocess.Popen(cmdCpuMaxFreq, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
    maxFreq_output, maxFreq_error = maxFreq_result.communicate(timeout=600)

    cmdCpuCurFreq = 'adb shell cat /sys/devices/system/cpu/cpu' + "{}".format(i) + '/cpufreq/cpuinfo_cur_freq'
    cmdCpuMaxFreq = 'adb shell cat /sys/devices/system/cpu/cpu' + "{}".format(i) + '/cpufreq/cpuinfo_max_freq'
    cmdCpuMinFreq = 'adb shell cat /sys/devices/system/cpu/cpu' + "{}".format(i) + '/cpufreq/cpuinfo_min_freq'
    curFreq_result = subprocess.Popen(cmdCpuCurFreq, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
    curFreq_output, curFreq_error = curFreq_result.communicate(timeout=600)

    minFreq_result = subprocess.Popen(cmdCpuMinFreq, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
    minFreq_output, minFreq_error = minFreq_result.communicate(timeout=600)

    if i == 0 :
        x0.append(int(curFreq_output.decode()))
    elif i == 1 :
        x1.append(int(curFreq_output.decode()))
    elif i == 2 :
        x2.append(int(curFreq_output.decode()))
    elif i == 3 :
        x3.append(int(curFreq_output.decode()))
    elif i == 4 :
        x4.append(int(curFreq_output.decode()))
    elif i == 5 :
        x5.append(int(curFreq_output.decode()))
    elif i == 6 :
        x6.append(int(curFreq_output.decode()))
    elif i == 7 :
        x7.append(int(curFreq_output.decode()))

    print('-')
    print(maxFreq_output.decode())
    print(curFreq_output.decode())
    print(minFreq_output.decode())
    print(i, '\n')
#         print(x0, x1, x2, x3, x4, x5, x6, x7)
# print(x0)
# print(x1)
# print(x2)
# print(x3)
# print(x4)
# print(x5)
# print(x6)
# print(x7)
#     print(cmdCpuCurFreq)
    

# result1 = subprocess.Popen(cmd1, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
# result2 = subprocess.Popen(cmd2, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
# output1, error1 = result1.communicate(timeout=600)
# output2, error2 = result2.communicate(timeout=600)
# print(x)
# print(output1.decode())
# print(output2.decode())
# Out:
# customer:
# producer
# producer
# customer:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20144/3330986802.py in <module>
#      17 # for num in range(10) :
#      18 for i in range(8) :
# ---> 19     maxFreq_result = subprocess.Popen(cmdCpuMaxFreq, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
#      20     maxFreq_output, maxFreq_error = maxFreq_result.communicate(timeout=600)
#      21
#
# NameError: name 'cmdCpuMaxFreq' is not defined
# customer:
# producer
# producer
# customer:
# customer:
# producer
# producer
# customer:
# customer:
# producer
# producer
# customer:
# customer:
# producer
# producer
# customer:
# customer:
# producer
# producer
# customer:
# customer:
# producerproducer
#
# customer:
# customer:
# producer
# producer
# customer:

# %%
import matplotlib.pyplot as plt

x_values = list(range(0, 10, 1))

plt.plot(x_values, x0)
plt.ylabel("Hz")

plt.show()
# Out:
# producerproducer
#
# customer:
# customer:
# producerproducer
#
# customer:
# customer:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20144/3726093741.py in <module>
#       3 x_values = list(range(0, 10, 1))
#       4
# ----> 5 plt.plot(x_values, x0)
#       6 plt.ylabel("Hz")
#       7
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...

# %%
# %matplotlib inline
# from IPython.core.pylabtools import figsize # import figsize
# figsize(12.5, 4)

plt.ion()

plt.subplot(811)
plt.plot(x_values, x0)

plt.subplot(812)
plt.plot(x_values, x1)

plt.subplot(813)
plt.plot(x_values, x2)

plt.subplot(814)
plt.plot(x_values, x3)

plt.subplot(815)
plt.plot(x_values, x4)

plt.subplot(816)
plt.plot(x_values, x5)

plt.subplot(817)
plt.plot(x_values, x6)

plt.subplot(818)
plt.plot(x_values, x7)

# plt.savefig(1.pdf)
plt.ioff()
# plt.show()
plt.pause(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20144/204016738.py in <module>
#       6
#       7 plt.subplot(811)
# ----> 8 plt.plot(x_values, x0)
#       9
#      10 plt.subplot(812)
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib qt5
from IPython import display
import math
import time

 
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

ax.set_xlabel('Time')
ax.set_ylabel('cos(t)')
ax.set_title('')

line = None
plt.grid(True) #添加网格
plt.ion()  #interactive mode on
obsX = []
obsY = []

t0 = time.time()

while True:
    t = time.time()-t0
    obsX.append(t)
    obsY.append(math.cos(2*math.pi*1*t))

    if line is None:
        line = ax.plot(obsX,obsY,'-g',marker='*')[0]

    line.set_xdata(obsX)
    line.set_ydata(obsY)

    ax.set_xlim([t-10,t+1])
    ax.set_ylim([-1,1])

    plt.pause(0.01)

# %% [markdown]
# ## 2020.1.4

# %% [markdown]
# 设置一个共享队列，然后边读(读的时候进行下一次数据的准备)边可视化
# 1. 开一个全局字典，控制访问

# %%
# /usr/bin/python
# encoding:utf-8
import csv
import os
import time

# 监控CPU资源信息
class MonitoringCPUResources(object):
    def __init__(self, count):
        self.counter = count
        self.alldata = [("timestamp", "cpustatus")]
    # 单次执行监控过程
    def monitoring(self):
        result = os.popen("adb shell cat /sys/devices/system/cpu/cpu0/cpufreq/cpuinfo_cur_freq")
        cpuvalue = result.readline().split("%")[0].strip()
        currenttime = self.getCurrentTime()
        print("current time is:"+currenttime)
        print("cpu used is:" + cpuvalue)
        self.alldata.append([currenttime, cpuvalue])
    # 多次执行监控过程
    def run(self):
        while self.counter > 0:
            self.monitoring()
            self.counter = self.counter - 1
            time.sleep(3)
    # 获取当前的时间戳
    def getCurrentTime(self):
        currentTime = time.strftime("%H:%M:%S", time.localtime())
        return currentTime
    # 数据的存储
    def SaveDataToCSV(self):
        csvfile = open('cpustatus.csv', 'w',encoding='utf8',newline='')
        writer = csv.writer(csvfile)
        writer.writerows(self.alldata)
        csvfile.close()
if __name__ == "__main__":
    monitoringCPUResources = MonitoringCPUResources(20)
    monitoringCPUResources.run()
    monitoringCPUResources.SaveDataToCSV()
# Out:
# current time is:16:37:24
# cpu used is:614400
# current time is:16:37:28
# cpu used is:614400
# current time is:16:37:31
# cpu used is:614400
# current time is:16:37:35
# cpu used is:614400
# current time is:16:37:39
# cpu used is:1363200
# current time is:16:37:42
# cpu used is:614400
# current time is:16:37:46
# cpu used is:864000
# current time is:16:37:49
# cpu used is:614400
# current time is:16:37:53
# cpu used is:614400
# current time is:16:37:57
# cpu used is:614400
# current time is:16:38:00
# cpu used is:864000
# current time is:16:38:04
# cpu used is:864000
# current time is:16:38:07
# cpu used is:614400
# current time is:16:38:11
# cpu used is:614400
# current time is:16:38:14
# cpu used is:614400
# current time is:16:38:18
# cpu used is:864000
# current time is:16:38:22
# cpu used is:614400
# current time is:16:38:25
# cpu used is:614400
# current time is:16:38:29
# cpu used is:614400
# current time is:16:38:32
# cpu used is:864000

# %%
import matplotlib.pyplot as plt
# %matplotlib qt5
from IPython import display
import numpy as np

fig,ax=plt.subplots()

lines1 = []
lines2 = []
with open("cpustatus.csv", 'r', encoding="utf-8") as csvfile :
    reader = csv.reader(csvfile)
    next(reader)
    for row in reader :
#         ax.plot(str(row[0]), int(row[1]))
#         plt.pause(3)
        lines1.append(row[0])
        lines2.append(row[1])

        ax.plot(lines1, lines2)
        plt.pause(0.03)#(1e-2)        
# print(lines1)
# print(lines2)
# plt.show()

# %%
from multiprocessing import Process, Queue
import time
import random
import gevent


# 消费者方法
def consumer(q):
    while True:
        time.sleep(2)
        gevent_data_list = []
        gevent_data_list.append(gevent.spawn(pop_data, q))
        gevent.joinall(gevent_data_list)


def pop_data(q):
    res = q.get()
    print("消费了%s " % (res))


# 生产者方法
def producer(q):
    class MonitoringCPUResources(object):
        def __init__(self, count):
            self.counter = count
            self.alldata = [("timestamp", "cpustatus")]
        # 单次执行监控过程
        def monitoring(self):
            result = os.popen("adb shell cat /sys/devices/system/cpu/cpu0/cpufreq/cpuinfo_cur_freq")
            cpuvalue = result.readline().split("%")[0].strip()
            currenttime = self.getCurrentTime()
            print("current time is:"+currenttime)
            print("cpu used is:" + cpuvalue)
            self.alldata.append([currenttime, cpuvalue])
        # 多次执行监控过程
        def run(self):
            while self.counter > 0:
                self.monitoring()
                self.counter = self.counter - 1
                time.sleep(3)
        # 获取当前的时间戳
        def getCurrentTime(self):
            currentTime = time.strftime("%H:%M:%S", time.localtime())
            return currentTime
        # 数据的存储
        def SaveDataToCSV(self):
            csvfile = open('cpustatus.csv', 'w',encoding='utf8',newline='')
            writer = csv.writer(csvfile)
            writer.writerows(self.alldata)
            csvfile.close()
            
    monitoringCPUResources = MonitoringCPUResources(20)
    monitoringCPUResources.run()
    monitoringCPUResources.SaveDataToCSV()
    
    # for i in range(10):
    while True:
        time.sleep(1)
        number = random.randint(1, 10)
        print("生产了 %s" % (number))
        q.put(number)


if __name__ == "__main__":
    # 创建队列
    q = Queue()

    # 创建生产者
    p1 = Process(target=producer, args=(q,))
    c1 = Process(target=consumer, args=(q,))
    p1.start()
    c1.start()

# %% [markdown]
# 2022.1.4 晚上在家
# 1. threading库提供了join方法。但是由于matplotlib.pyplot中的方法都是全局的，因此用多线程绘图会有错误：RuntimeError: main thread is not in main loop
# 2. 多线程不能使用matplotlib.pyplot绘图，解决办法：尝试使用多线程----->图片不显示

# %%
from datetime import datetime
from queue import Queue
import threading
import time
import random
import matplotlib.pyplot as plt
# %matplotlib qt5
# %matplotlib inline
from IPython import display

# from multiprocessing import Process, Queue, Lock


fig = plt.figure()

ax0 = fig.add_subplot(811)

line = None
plt.grid(True) #添加网格
plt.ion()  #interactive mode on


obsX = []
x0 = []
queue = Queue(maxsize=100) #设置队列最大空间为100
# lock = threading.Lock()
# lock = Lock()

def producer(queue) :
#     lock.acquire()

    data = {}
    while True :
        cur_time = time.time() 
        cur_cpu0 = random.random() #可以改成cpu的时间
        data = {
            "time" : cur_time,
            "cpu0" : cur_cpu0
        }
        queue.put(data)
        print("producer")
        time.sleep(1)

        
#         lock.release()
        
def customer(queue) :
#     lock.acquire()
    while True :
#         test = queue.get()
#         print(test)
#         print(list(test.values())[0])
#         print(list(test.values())[1])
        if not queue.empty() :
            tmp = queue.get()

            _cur_time = list(tmp.values())[0]
            _cur_cpu0 = list(tmp.values())[1]

#             obsX = []
#             x0 = []
            
            obsX.append(_cur_time)
            x0.append(_cur_cpu0)
#             ## 每150个点显示一次
#             num = 150
#             while num > 0:
#                 obsX.append(_cur_time)
#                 x0.append(_cur_cpu0)
#                 num -= 1
#             if line is None :
#                 line0 = ax0.plot(obsX, x0)

#             print(obsX)
#             print(x0)
#             plt.pause(0.3)
    #         plt.show()

#             time.sleep(1)
            print("customer:")
            time.sleep(1)
        else :
            print('wcustomerait for seconds...')
            time.sleep(1)
    
#     lock.release()

if __name__ == '__main__' :
    p1_thread = threading.Thread(target=producer, args=(queue, ))
    c1_thread = threading.Thread(target=customer, args=(queue, ))
    p1_thread.start()
    c1_thread.start()
    
#     queue = Queue()
#     p1_process = Process(target=producer, args=(queue, ))
#     c1_process = Process(target=customer, args=(queue, ))
#     p1_process.start()
#     c1_process.start()
#     p1_process.join()
#     c1_process.join()
    print("ok")
# Out:
# producer
# customer:ok
#
# customer:
# producer
# producer
# customer:
# customer:
# producer

# %% [markdown]
# 把绘图函数单独写成一个进程，闪退
#
# https://www.cnblogs.com/zealousness/p/9753282.html

# %%
from datetime import datetime
# from queue import Queue
import threading
import time
import random
import matplotlib.pyplot as plt
# %matplotlib qt5
# %matplotlib inline
from IPython import display

from multiprocessing import Process, Queue, Lock


# fig = plt.figure()

# ax0 = fig.add_subplot(811)

# line = None
# plt.grid(True) #添加网格
# plt.ion()  #interactive mode on

obsX = []
x0 = []

queue = Queue(maxsize=100) #设置队列最大空间为100
# lock = threading.Lock()
# lock = Lock()

def producer(queue) :
#     lock.acquire()
    
    data = {}
    while True :
        cur_time = time.time() 
        cur_cpu0 = random.random() #可以改成cpu的时间
        data = {
            "time" : cur_time,
            "cpu0" : cur_cpu0
        }
        queue.put(data)
        
        time.sleep(0.1)
        
#         lock.release()
        
def customer(queue) :
#     lock.acquire()
    while True :
#         test = queue.get()
#         print(test)
#         print(list(test.values())[0])
#         print(list(test.values())[1])
        if not queue.empty() :
            tmp = queue.get()

            _cur_time = list(tmp.values())[0]
            _cur_cpu0 = list(tmp.values())[1]

#             obsX = []
#             x0 = []
            
            obsX.append(_cur_time)
            x0.append(_cur_cpu0)
            

#             ## 每150个点显示一次
#             num = 150
#             while num > 0:
#                 obsX.append(_cur_time)
#                 x0.append(_cur_cpu0)
#                 num -= 1
#             if line is None :
#                 line0 = ax0.plot(obsX, x0)
#             print("customer:")
#             print(obsX)
#             print(x0)
#             plt.pause(0.3)
    #         plt.show()

#             time.sleep(1)
        else :
            print('wait for seconds...')
            time.sleep(1)

#     lock.release()

def show_figure(x,y):
    fig = plt.figure()
    ax0 = fig.add_subplot(811)
    line = None
    plt.grid(True) #添加网格
    plt.ion()  #interactive mode on
    
    if line is None :
        line0 = ax0.plot(x, y)
    plt.pause(0.03)

if __name__ == '__main__' :
#     p1_thread = threading.Thread(target=producer, args=(queue, ))
#     c1_thread = threading.Thread(target=customer, args=(queue, ))
#     p1_thread.start()
#     c1_thread.start()
    
#     queue = Queue()
    p1_process = Process(target=producer, args=(queue, ))
    c1_process = Process(target=customer, args=(queue, ))
    show_process = Process(target=show_figure, args=(obsX, x0, ))
    
    p1_process.start()
    c1_process.start()
    show_process.start()
    
    p1_process.join()
    c1_process.join()
    show_process.join()
    print("ok")
# Out:
# ok

# %% [markdown]
# ## 2022.1.5

# %%
# Out:
# producer
# customer:
# producer
# customer:
# producer
# customer:
# producer
# customer:
# producer
# customer:
