# %%
import os
import subprocess
import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib qt5
from IPython import display
import random
import pandas as pd
import datetime

cmd1 = 'adb connect  10.10.25.2:5555'
subprocess.Popen(cmd1, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
 
fig = plt.figure()

ax0 = fig.add_subplot(811)
ax1 = fig.add_subplot(812)
ax2 = fig.add_subplot(813)
ax3 = fig.add_subplot(814)
ax4 = fig.add_subplot(815)
ax5 = fig.add_subplot(816)
ax6 = fig.add_subplot(817)
ax7 = fig.add_subplot(818)


ax0.set_xlabel('Time')
ax0.set_ylabel('cpu0')
ax0.set_title('')
ax1.set_xlabel('Time')
ax1.set_ylabel('cpu1')
ax2.set_xlabel('Time')
ax2.set_ylabel('cpu2')
ax3.set_xlabel('Time')
ax3.set_ylabel('cpu3')
ax4.set_xlabel('Time')
ax4.set_ylabel('cpu4')
ax5.set_xlabel('Time')
ax5.set_ylabel('cpu5')
ax6.set_xlabel('Time')
ax6.set_ylabel('cpu6')
ax7.set_xlabel('Time')
ax7.set_ylabel('cpu7')

line = None
plt.grid(True) #添加网格
plt.ion()  #interactive mode on
obsX = []


x0 = []
x1 = []
x2 = []
x3 = []
x4 = []
x5 = []
x6 = []
x7 = []

test1 = []
test2 = []
test3 = []
test4 = []
test5 = []


t0 = time.time()#round(time.time() * 1000)
# int(round(t * 1000))

# while True:
for i in range(200) :

#     t0 = time.time()
    
#     x0.append(random.random())
#     x1.append(random.random())
#     x2.append(random.random())
#     x3.append(random.random())
#     x4.append(random.random())
#     x5.append(random.random())
#     x6.append(random.random())
#     x7.append(random.random())
    
    for i in range(8) :
        cmdCpuCurFreq = 'adb shell cat /sys/devices/system/cpu/cpu' + "{}".format(i) + '/cpufreq/cpuinfo_cur_freq'
        curFreq_result = subprocess.Popen(cmdCpuCurFreq, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
        curFreq_output, curFreq_error = curFreq_result.communicate(timeout=600)

        if i == 0 :
            x0.append(int(curFreq_output.decode()) / 1000000)
#             print('x0', x0)
        elif i == 1 :
            x1.append(int(curFreq_output.decode()) / 1000000)
#             print('x1', x1)
        elif i == 2 :
            x2.append(int(curFreq_output.decode()) / 1000000)
#             print('x2', x2)
        elif i == 3 :
            x3.append(int(curFreq_output.decode()) / 1000000)
#             print('x3', x3)
        elif i == 4 :
            x4.append(int(curFreq_output.decode()) / 1000000)
#             print('x4', x4)
        elif i == 5 :
            x5.append(int(curFreq_output.decode()) / 1000000)
#             print('x5', x5)
        elif i == 6 :
            x6.append(int(curFreq_output.decode()) / 1000000)
#             print('x6', x6)
        elif i == 7 :
            x7.append(int(curFreq_output.decode()) / 1000000)
#             print('x7', x7)
     
    
    t = time.time()
    obsX.append(t)
    
    if line is None:
        line0 = ax0.plot(obsX, x0)
        line1 = ax1.plot(obsX, x1)
        line2 = ax2.plot(obsX, x2)
        line3 = ax3.plot(obsX, x3)
        line4 = ax4.plot(obsX, x4)
        line5 = ax5.plot(obsX, x5)
        line6 = ax6.plot(obsX, x6)
        line7 = ax7.plot(obsX, x7)

    plt.pause(0.03)
    
#     ax0.cla()
#     ax1.cla()
#     ax2.cla()
#     ax3.cla()
#     ax4.cla()
#     ax5.cla()
#     ax6.cla()
#     ax7.cla()

plt.show()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "E:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\baoer\AppData\Local\Temp/ipykernel_20316/2367519280.py", line 9, in <module>
#     import pandas as pd
#   File "E:\Software\Anaconda\lib\site-packages\pandas\__init__.py", line 143, in <module>
#     from pandas.io.api import (
#   File "E:\Software\Anaconda\lib\site-packages\pandas\io\api.py", line 8, in <module>
#     from pandas.io.excel import (
#   File "E:\Software\Anaconda\lib\site-packages\pandas\io\excel\__init__.py", line 1, in <module>
#     from pandas.io.excel._base import (
#   File "E:\Software\Anaconda\lib\site-packages\pandas\io\excel\_base.py", line 1105, in <module>
#     class ExcelFile:
#   File "E:\Software\Anaconda\lib\site-packages\pandas\io\excel\_base.py", line 1154, in ExcelFile
#     from pandas.io.excel._odfreader import ODFReader
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 935, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1079, in path_stats
#   File "<frozen importlib._bootstrap_external>", line 142, in _path_stat
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\Software\Anaconda\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "E:\Software\Anaconda\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "E:\Software\Anaconda\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "E:\Software\Anaconda\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "E:\Software\Anaconda\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "E:\Software\Anaconda\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "E:\Software\Anaconda\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "E:\Software\Anaconda\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_20316/2367519280.py in <module>
#       8 import random
# ----> 9 import pandas as pd
#      10 import datetime
#
# E:\Software\Anaconda\lib\site-packages\pandas\__init__.py in <module>
#     142
# --> 143 from pandas.io.api import (
#     144     # excel
#
# E:\Software\Anaconda\lib\site-packages\pandas\io\api.py in <module>
#       7 from pandas.io.clipboards import read_clipboard
# ----> 8 from pandas.io.excel import (
#       9     ExcelFile,
#
# E:\Software\Anaconda\lib\site-packages\pandas\io\excel\__init__.py in <module>
# ----> 1 from pandas.io.excel._base import (
#       2     ExcelFile,
#       3     ExcelWriter,
#
# E:\Software\Anaconda\lib\site-packages\pandas\io\excel\_base.py in <module>
#    1104
# -> 1105 class ExcelFile:
#    1106     """
#
# E:\Software\Anaconda\lib\site-packages\pandas\io\excel\_base.py in ExcelFile()
#    1153
# -> 1154     from pandas.io.excel._odfreader import ODFReader
#    1155     from pandas.io.excel._openpyxl import OpenpyxlReader
#
# E:\Software\Anaconda\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# E:\Software\Anaconda\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# E:\Software\Anaconda\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# E:\Software\Anaconda\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# E:\Software\Anaconda\lib\importlib\_bootstrap_external.py in get_code(self, fullname)
#
# E:\Software\Anaconda\lib\importlib\_bootstrap_external.py in path_stats(self, path)
#
# E:\Software\Anaconda\lib\importlib\_bootstrap_external.py in _path_stat(path)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# E:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2063                         # in the engines. This should return a list of strings.
# -> 2064                         stb = value._render_traceback_()
#    2065                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# E:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2064                         stb = value._render_traceback_()
#    2065                     except Exception:
# -> 2066                         stb = self.InteractiveTB.structured_traceback(etype,
#    2067                                             value, tb, tb_offset=tb_offset)
#    2068
#
# E:\Software\Anaconda\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# E:\Software\Anaconda\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# E:\Software\Anaconda\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# E:\Software\Anaconda\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# E:\Software\Anaconda\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# 截取的3张图像如下
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
import os
import subprocess
import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib qt5
from IPython import display
import random
import pandas as pd
import datetime

cmd1 = 'adb connect  10.10.25.2:5555'
subprocess.Popen(cmd1, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
 
fig = plt.figure()

ax0 = fig.add_subplot(811)
ax1 = fig.add_subplot(812)
ax2 = fig.add_subplot(813)
ax3 = fig.add_subplot(814)
ax4 = fig.add_subplot(815)
ax5 = fig.add_subplot(816)
ax6 = fig.add_subplot(817)
ax7 = fig.add_subplot(818)


ax0.set_xlabel('Time')
ax0.set_ylabel('cpu0')
ax0.set_title('')
ax1.set_xlabel('Time')
ax1.set_ylabel('cpu1')
ax2.set_xlabel('Time')
ax2.set_ylabel('cpu2')
ax3.set_xlabel('Time')
ax3.set_ylabel('cpu3')
ax4.set_xlabel('Time')
ax4.set_ylabel('cpu4')
ax5.set_xlabel('Time')
ax5.set_ylabel('cpu5')
ax6.set_xlabel('Time')
ax6.set_ylabel('cpu6')
ax7.set_xlabel('Time')
ax7.set_ylabel('cpu7')

line = None
plt.grid(True) #添加网格
plt.ion()  #interactive mode on
obsX = []


x0 = []
x1 = []
x2 = []
x3 = []
x4 = []
x5 = []
x6 = []
x7 = []

test1 = []
test2 = []
test3 = []
test4 = []
test5 = []


t0 = time.time()#round(time.time() * 1000)
# int(round(t * 1000))

while True:
# for i in range(200) :

#     t0 = time.time()
    
    x0.append(random.random())
    x1.append(random.random())
    x2.append(random.random())
    x3.append(random.random())
    x4.append(random.random())
    x5.append(random.random())
    x6.append(random.random())
    x7.append(random.random())
    
#     for i in range(8) :
#         cmdCpuCurFreq = 'adb shell cat /sys/devices/system/cpu/cpu' + "{}".format(i) + '/cpufreq/cpuinfo_cur_freq'
#         curFreq_result = subprocess.Popen(cmdCpuCurFreq, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
#         curFreq_output, curFreq_error = curFreq_result.communicate(timeout=600)

#         if i == 0 :
#             x0.append(int(curFreq_output.decode()) / 1000000)
# #             print('x0', x0)
#         elif i == 1 :
#             x1.append(int(curFreq_output.decode()) / 1000000)
# #             print('x1', x1)
#         elif i == 2 :
#             x2.append(int(curFreq_output.decode()) / 1000000)
# #             print('x2', x2)
#         elif i == 3 :
#             x3.append(int(curFreq_output.decode()) / 1000000)
# #             print('x3', x3)
#         elif i == 4 :
#             x4.append(int(curFreq_output.decode()) / 1000000)
# #             print('x4', x4)
#         elif i == 5 :
#             x5.append(int(curFreq_output.decode()) / 1000000)
# #             print('x5', x5)
#         elif i == 6 :
#             x6.append(int(curFreq_output.decode()) / 1000000)
# #             print('x6', x6)
#         elif i == 7 :
#             x7.append(int(curFreq_output.decode()) / 1000000)
# #             print('x7', x7)
     
    
    t = time.time()
    obsX.append(t)
    
    if line is None:
        line0 = ax0.plot(obsX, x0)
        line1 = ax1.plot(obsX, x1)
        line2 = ax2.plot(obsX, x2)
        line3 = ax3.plot(obsX, x3)
        line4 = ax4.plot(obsX, x4)
        line5 = ax5.plot(obsX, x5)
        line6 = ax6.plot(obsX, x6)
        line7 = ax7.plot(obsX, x7)
    
    ax0.set_xlim([t-5,t + 1])
    ax1.set_xlim([t-5,t + 1])
    ax2.set_xlim([t-5,t + 1])
    ax3.set_xlim([t-5,t + 1])
    ax4.set_xlim([t-5,t + 1])
    ax5.set_xlim([t-5,t + 1])
    ax6.set_xlim([t-5,t + 1])
    ax7.set_xlim([t-5,t + 1])
    plt.pause(0.03)
    
#     ax0.cla()
#     ax1.cla()
#     ax2.cla()
#     ax3.cla()
#     ax4.cla()
#     ax5.cla()
#     ax6.cla()
#     ax7.cla()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# E:\Software\Anaconda\lib\site-packages\matplotlib\backends\backend_qt5.py in _draw_idle(self)
#     473                 return
#     474             try:
# --> 475                 self.draw()
#     476             except Exception:
#     477                 # Uncaught exceptions are fatal for PyQt5, so catch them.
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2788
#    2789             self.patch.draw(renderer)
# -> 2790             mimage._draw_list_compositing_images(
#    2791                 renderer, self, artists, self.suppressComposite)
#    2792
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2919             renderer.stop_rasterizing()
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#    2923         renderer.close_group('axes')
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\lines.py in draw(self, renderer)
#     794
#     795                 gc.set_dashes(self._dashOffset, self._dashSeq)
# --> 796                 renderer.draw_path(gc, tpath, affine.frozen())
#     797                 gc.restore()
#     798
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\transforms.py in frozen(self)
#    1813     def frozen(self):
#    1814         # docstring inherited
# -> 1815         return Affine2D(self.get_matrix().copy())
#    1816
#    1817     @property
#
# E:\Software\Anaconda\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1879             # A bit faster than np.identity(3).
#    1880             matrix = IdentityTransform._mtx.copy()
# -> 1881         self._mtx = matrix.copy()
#    1882         self._invalid = 0
#    1883
#
# KeyboardInterrupt:

# %% [markdown]
# 使用随机数进行测试，无卡顿
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
